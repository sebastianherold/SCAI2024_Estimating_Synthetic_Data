# %%
# %load_ext jupyternotify

# %%
# %%timeit

# %run Step2-Model.ipynb
# %notify -m "Step 2: ML models finished!"
# Out:
# <style type="text/css">
# #T_e6491_row8_col1, #T_e6491_row10_col1, #T_e6491_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e6491">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6491_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e6491_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6491_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6491_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e6491_row0_col1" class="data row0 col1" >719</td>
#     </tr>
#     <tr>
#       <th id="T_e6491_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6491_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e6491_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
# ...

# %%
# %%timeit


# %run Step3-SDG.ipynb
# %notify -m "Step 3: SDG finished!"

# %%
# %%timeit

# %run Step4-SD_models.ipynb
# %notify -m "Step 4: SD ML models finished!"

# %%
# %%timeit

# %run Step5-Measures_PF.ipynb
# %notify -m "Step 5: Computing PF metrics finished!"
